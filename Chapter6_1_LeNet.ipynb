# %%
# %load_ext tensorboard

import datetime
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, AveragePooling2D, Dropout

num_classes = 2
class LeNet(Sequential):
    def __init__(self, input_shape, nb_classes):
        super().__init__()

        self.add(Conv2D(6, kernel_size=(5, 5), strides=(1, 1), activation='relu', input_shape=input_shape, padding="same"))
        self.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
        self.add(Conv2D(16, kernel_size=(5, 5), strides=(1, 1), activation='relu', padding='valid'))
        self.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
        self.add(Flatten())
        self.add(Dense(120, activation='relu'))
        self.add(Dense(84, activation='relu'))
        self.add(Dense(nb_classes, activation='softmax'))

        self.compile(optimizer='adam',
                    loss=categorical_crossentropy,
                    metrics=['accuracy'])

model = LeNet((100, 100, 3), num_classes)
model.summary()
# Out:
# Model: "le_net"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 6)       456
#
#  average_pooling2d (AverageP  (None, 50, 50, 6)        0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 46, 46, 16)        2416
#
#  average_pooling2d_1 (Averag  (None, 23, 23, 16)       0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 8464)              0
#
#  dense (Dense)               (None, 120)               1015800
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dense_2 (Dense)             (None, 2)                 170
#
# =================================================================
# Total params: 1,029,006
# Trainable params: 1,029,006
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS = 100
BATCH_SIZE = 32
image_height = 100
image_width = 100

train_dir = "/Users/smk0728/Desktop/D_T_S/Image/chap6/data/catanddog/train"
valid_dir = "/Users/smk0728/Desktop/D_T_S/Image/chap6/data/catanddog/validation"

train = ImageDataGenerator(
                  rescale=1./255,
                  rotation_range=10,
                  width_shift_range=0.1,
                  height_shift_range=0.1,
                  shear_range=0.1,
                  zoom_range=0.1)

train_generator = train.flow_from_directory(train_dir,
                                                    target_size=(image_height, image_width),
                                                    color_mode="rgb",
                                                    batch_size=BATCH_SIZE,
                                                    seed=1,
                                                    shuffle=True,
                                                    class_mode="categorical")

valid = ImageDataGenerator(rescale=1.0/255.0)
valid_generator = valid.flow_from_directory(valid_dir,
                                                    target_size=(image_height, image_width),
                                                    color_mode="rgb",
                                                    batch_size=BATCH_SIZE,
                                                    seed=7,
                                                    shuffle=True,
                                                    class_mode="categorical"
                                                    )
train_num = train_generator.samples
valid_num = valid_generator.samples
# Out:
# Found 385 images belonging to 2 classes.
# Found 98 images belonging to 2 classes.

# %%
# TensorBoard 에서 훈련과정 보기
log_dir="../D_T_S/chap6/img/log6-1/"
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, profile_batch = 0)

# %%
# 모델 훈련
model.fit(train_generator,
                    epochs=EPOCHS,
                    steps_per_epoch=train_num // BATCH_SIZE,
                    validation_data=valid_generator,
                    validation_steps=valid_num // BATCH_SIZE,
                    callbacks=[tensorboard_callback],
                    verbose=1)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 5s 152ms/step - loss: 0.7963 - accuracy: 0.5326 - val_loss: 0.6926 - val_accuracy: 0.5000
# Epoch 2/100
# 12/12 [==============================] - 1s 98ms/step - loss: 0.6956 - accuracy: 0.4731 - val_loss: 0.6930 - val_accuracy: 0.5000
# Epoch 3/100
# 12/12 [==============================] - 1s 99ms/step - loss: 0.6938 - accuracy: 0.4788 - val_loss: 0.6924 - val_accuracy: 0.5104
# Epoch 4/100
# 12/12 [==============================] - 1s 109ms/step - loss: 0.6916 - accuracy: 0.4986 - val_loss: 0.6963 - val_accuracy: 0.5000
# Epoch 5/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.6878 - accuracy: 0.5411 - val_loss: 0.7126 - val_accuracy: 0.4896
# Epoch 6/100
# 12/12 [==============================] - 1s 97ms/step - loss: 0.6930 - accuracy: 0.5099 - val_loss: 0.6924 - val_accuracy: 0.6146
# Epoch 7/100
# 12/12 [==============================] - 1s 99ms/step - loss: 0.6928 - accuracy: 0.5297 - val_loss: 0.6926 - val_accuracy: 0.5104
# Epoch 8/100
# 12/12 [==============================] - 1s 109ms/step - loss: 0.6920 - accuracy: 0.5382 - val_loss: 0.6924 - val_accuracy: 0.5208
# Epoch 9/100
# 12/12 [==============================] - 1s 113ms/step - loss: 0.6914 - accuracy: 0.5354 - val_loss: 0.6915 - val_accuracy: 0.5312
# Epoch 10/100
# 12/12 [==============================] - 1s 97ms/step - loss: 0.6877 - accuracy: 0.5496 - val_loss: 0.6804 - val_accuracy: 0.5417
# Epoch 11/100
# 12/12 [==============================] - 1s 110ms/step - loss: 0.6840 - accuracy: 0.5599 - val_loss: 0.6846 - val_accuracy: 0.5521
# Epoch 12/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.6811 - accuracy: 0.6062 - val_loss: 0.6908 - val_accuracy: 0.5417
# Epoch 13/100
# 12/12 [==============================] - 1s 109ms/step - loss: 0.6668 - accuracy: 0.5781 - val_loss: 0.6821 - val_accuracy: 0.5938
# Epoch 14/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.6691 - accuracy: 0.6317 - val_loss: 0.6609 - val_accuracy: 0.5729
# Epoch 15/100
# 12/12 [==============================] - 1s 106ms/step - loss: 0.6552 - accuracy: 0.6657 - val_loss: 0.6683 - val_accuracy: 0.6042
# Epoch 16/100
# 12/12 [==============================] - 1s 91ms/step - loss: 0.6431 - accuracy: 0.6176 - val_loss: 0.6819 - val_accuracy: 0.5104
# Epoch 17/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.6870 - accuracy: 0.5382 - val_loss: 0.6878 - val_accuracy: 0.5312
# Epoch 18/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.6881 - accuracy: 0.5637 - val_loss: 0.6873 - val_accuracy: 0.5521
# Epoch 19/100
# 12/12 [==============================] - 1s 98ms/step - loss: 0.6837 - accuracy: 0.6119 - val_loss: 0.6729 - val_accuracy: 0.5833
# Epoch 20/100
# 12/12 [==============================] - 1s 114ms/step - loss: 0.6767 - accuracy: 0.5911 - val_loss: 0.6550 - val_accuracy: 0.6667
# Epoch 21/100
# 12/12 [==============================] - 1s 117ms/step - loss: 0.6600 - accuracy: 0.6346 - val_loss: 0.6393 - val_accuracy: 0.6458
# Epoch 22/100
# 12/12 [==============================] - 2s 130ms/step - loss: 0.6431 - accuracy: 0.6856 - val_loss: 0.6583 - val_accuracy: 0.6354
# Epoch 23/100
# 12/12 [==============================] - 1s 109ms/step - loss: 0.6440 - accuracy: 0.6346 - val_loss: 0.6428 - val_accuracy: 0.6354
# Epoch 24/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.6371 - accuracy: 0.6431 - val_loss: 0.6623 - val_accuracy: 0.6042
# Epoch 25/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.6859 - accuracy: 0.6119 - val_loss: 0.6717 - val_accuracy: 0.6250
# Epoch 26/100
# 12/12 [==============================] - 1s 105ms/step - loss: 0.6387 - accuracy: 0.6544 - val_loss: 0.7000 - val_accuracy: 0.5833
# Epoch 27/100
# 12/12 [==============================] - 1s 97ms/step - loss: 0.6225 - accuracy: 0.6431 - val_loss: 0.6804 - val_accuracy: 0.5521
# Epoch 28/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.6163 - accuracy: 0.6827 - val_loss: 0.7476 - val_accuracy: 0.5938
# Epoch 29/100
# 12/12 [==============================] - 1s 111ms/step - loss: 0.6297 - accuracy: 0.6346 - val_loss: 0.8334 - val_accuracy: 0.5417
# Epoch 30/100
# 12/12 [==============================] - 1s 107ms/step - loss: 0.6442 - accuracy: 0.6204 - val_loss: 0.6531 - val_accuracy: 0.6250
# Epoch 31/100
# 12/12 [==============================] - 1s 106ms/step - loss: 0.5977 - accuracy: 0.6912 - val_loss: 0.7340 - val_accuracy: 0.5833
# Epoch 32/100
# 12/12 [==============================] - 1s 105ms/step - loss: 0.6360 - accuracy: 0.6261 - val_loss: 0.6770 - val_accuracy: 0.6146
# Epoch 33/100
# 12/12 [==============================] - 1s 113ms/step - loss: 0.6447 - accuracy: 0.6204 - val_loss: 0.6824 - val_accuracy: 0.5833
# Epoch 34/100
# 12/12 [==============================] - 2s 129ms/step - loss: 0.6373 - accuracy: 0.6261 - val_loss: 0.6973 - val_accuracy: 0.5833
# Epoch 35/100
# 12/12 [==============================] - 1s 105ms/step - loss: 0.6032 - accuracy: 0.6912 - val_loss: 0.7573 - val_accuracy: 0.5521
# Epoch 36/100
# 12/12 [==============================] - 1s 110ms/step - loss: 0.6118 - accuracy: 0.6317 - val_loss: 0.6812 - val_accuracy: 0.5938
# Epoch 37/100
# 12/12 [==============================] - 1s 109ms/step - loss: 0.5841 - accuracy: 0.6912 - val_loss: 0.7792 - val_accuracy: 0.5208
# Epoch 38/100
# 12/12 [==============================] - 1s 105ms/step - loss: 0.5647 - accuracy: 0.7025 - val_loss: 0.7315 - val_accuracy: 0.5833
# Epoch 39/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.5648 - accuracy: 0.7025 - val_loss: 0.7315 - val_accuracy: 0.5312
# Epoch 40/100
# 12/12 [==============================] - 1s 105ms/step - loss: 0.5626 - accuracy: 0.7214 - val_loss: 0.6764 - val_accuracy: 0.5938
# Epoch 41/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.5833 - accuracy: 0.6884 - val_loss: 0.7228 - val_accuracy: 0.5833
# Epoch 42/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.5395 - accuracy: 0.6941 - val_loss: 0.7052 - val_accuracy: 0.5417
# Epoch 43/100
# 12/12 [==============================] - 1s 111ms/step - loss: 0.5708 - accuracy: 0.6875 - val_loss: 0.7373 - val_accuracy: 0.5938
# Epoch 44/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.5140 - accuracy: 0.7252 - val_loss: 0.7643 - val_accuracy: 0.5833
# Epoch 45/100
# 12/12 [==============================] - 1s 114ms/step - loss: 0.5507 - accuracy: 0.6969 - val_loss: 0.7833 - val_accuracy: 0.6146
# Epoch 46/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.5068 - accuracy: 0.7564 - val_loss: 0.8973 - val_accuracy: 0.5833
# Epoch 47/100
# 12/12 [==============================] - 1s 95ms/step - loss: 0.5632 - accuracy: 0.7195 - val_loss: 0.7888 - val_accuracy: 0.5521
# Epoch 48/100
# 12/12 [==============================] - 1s 108ms/step - loss: 0.5253 - accuracy: 0.7240 - val_loss: 0.7382 - val_accuracy: 0.6146
# Epoch 49/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.4907 - accuracy: 0.7762 - val_loss: 0.7732 - val_accuracy: 0.6250
# Epoch 50/100
# 12/12 [==============================] - 1s 105ms/step - loss: 0.4734 - accuracy: 0.7649 - val_loss: 0.8940 - val_accuracy: 0.6458
# Epoch 51/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4869 - accuracy: 0.7656 - val_loss: 0.8992 - val_accuracy: 0.6146
# Epoch 52/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.4877 - accuracy: 0.7865 - val_loss: 0.7765 - val_accuracy: 0.6146
# Epoch 53/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4468 - accuracy: 0.7904 - val_loss: 0.9747 - val_accuracy: 0.5729
# Epoch 54/100
# 12/12 [==============================] - 1s 99ms/step - loss: 0.4719 - accuracy: 0.7969 - val_loss: 0.8133 - val_accuracy: 0.6354
# Epoch 55/100
# 12/12 [==============================] - 1s 94ms/step - loss: 0.4268 - accuracy: 0.8130 - val_loss: 0.8169 - val_accuracy: 0.6250
# Epoch 56/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.3799 - accuracy: 0.8281 - val_loss: 0.9596 - val_accuracy: 0.5938
# Epoch 57/100
# 12/12 [==============================] - 1s 97ms/step - loss: 0.4097 - accuracy: 0.7875 - val_loss: 1.0066 - val_accuracy: 0.6042
# Epoch 58/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4409 - accuracy: 0.7989 - val_loss: 0.9777 - val_accuracy: 0.5833
# Epoch 59/100
# 12/12 [==============================] - 1s 113ms/step - loss: 0.4224 - accuracy: 0.7734 - val_loss: 0.8183 - val_accuracy: 0.6042
# Epoch 60/100
# 12/12 [==============================] - 1s 106ms/step - loss: 0.4044 - accuracy: 0.8177 - val_loss: 0.8779 - val_accuracy: 0.5938
# Epoch 61/100
# 12/12 [==============================] - 1s 93ms/step - loss: 0.3965 - accuracy: 0.7960 - val_loss: 0.8419 - val_accuracy: 0.5938
# Epoch 62/100
# 12/12 [==============================] - 1s 98ms/step - loss: 0.3994 - accuracy: 0.8187 - val_loss: 1.0070 - val_accuracy: 0.6250
# Epoch 63/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.3845 - accuracy: 0.8102 - val_loss: 0.9946 - val_accuracy: 0.6146
# Epoch 64/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.3992 - accuracy: 0.8329 - val_loss: 0.9426 - val_accuracy: 0.6042
# Epoch 65/100
# 12/12 [==============================] - 1s 94ms/step - loss: 0.3797 - accuracy: 0.8215 - val_loss: 0.9612 - val_accuracy: 0.6146
# Epoch 66/100
# 12/12 [==============================] - 1s 98ms/step - loss: 0.3254 - accuracy: 0.8697 - val_loss: 1.1383 - val_accuracy: 0.6354
# Epoch 67/100
# 12/12 [==============================] - 1s 99ms/step - loss: 0.4127 - accuracy: 0.7904 - val_loss: 0.8884 - val_accuracy: 0.6562
# Epoch 68/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.3832 - accuracy: 0.8300 - val_loss: 0.8479 - val_accuracy: 0.6146
# Epoch 69/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.3401 - accuracy: 0.8646 - val_loss: 0.9310 - val_accuracy: 0.6146
# Epoch 70/100
# 12/12 [==============================] - 1s 96ms/step - loss: 0.2918 - accuracy: 0.8782 - val_loss: 1.1176 - val_accuracy: 0.6562
# Epoch 71/100
# 12/12 [==============================] - 1s 106ms/step - loss: 0.3630 - accuracy: 0.8584 - val_loss: 1.0423 - val_accuracy: 0.6771
# Epoch 72/100
# 12/12 [==============================] - 1s 108ms/step - loss: 0.2788 - accuracy: 0.8895 - val_loss: 1.0218 - val_accuracy: 0.6458
# Epoch 73/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.2699 - accuracy: 0.8802 - val_loss: 1.0338 - val_accuracy: 0.6667
# Epoch 74/100
# 12/12 [==============================] - 1s 95ms/step - loss: 0.2818 - accuracy: 0.8697 - val_loss: 1.2079 - val_accuracy: 0.6354
# Epoch 75/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.2254 - accuracy: 0.9122 - val_loss: 0.9762 - val_accuracy: 0.6146
# Epoch 76/100
# 12/12 [==============================] - 1s 99ms/step - loss: 0.2838 - accuracy: 0.8725 - val_loss: 1.2548 - val_accuracy: 0.6042
# Epoch 77/100
# 12/12 [==============================] - 1s 95ms/step - loss: 0.4200 - accuracy: 0.8045 - val_loss: 0.9168 - val_accuracy: 0.6354
# Epoch 78/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.3467 - accuracy: 0.8672 - val_loss: 0.9477 - val_accuracy: 0.6354
# Epoch 79/100
# 12/12 [==============================] - 1s 109ms/step - loss: 0.2841 - accuracy: 0.8782 - val_loss: 0.9758 - val_accuracy: 0.6771
# Epoch 80/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.2350 - accuracy: 0.9150 - val_loss: 1.0269 - val_accuracy: 0.6562
# Epoch 81/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.2366 - accuracy: 0.9037 - val_loss: 1.0751 - val_accuracy: 0.6562
# Epoch 82/100
# 12/12 [==============================] - 1s 95ms/step - loss: 0.2376 - accuracy: 0.9008 - val_loss: 1.2469 - val_accuracy: 0.6562
# Epoch 83/100
# 12/12 [==============================] - 1s 96ms/step - loss: 0.2303 - accuracy: 0.9093 - val_loss: 1.3789 - val_accuracy: 0.6146
# Epoch 84/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.2131 - accuracy: 0.9065 - val_loss: 1.4452 - val_accuracy: 0.6250
# Epoch 85/100
# 12/12 [==============================] - 1s 110ms/step - loss: 0.2613 - accuracy: 0.8895 - val_loss: 1.2152 - val_accuracy: 0.6354
# Epoch 86/100
# 12/12 [==============================] - 1s 98ms/step - loss: 0.2732 - accuracy: 0.8895 - val_loss: 1.4092 - val_accuracy: 0.6562
# Epoch 87/100
# 12/12 [==============================] - 1s 95ms/step - loss: 0.2571 - accuracy: 0.8980 - val_loss: 1.1288 - val_accuracy: 0.5729
# Epoch 88/100
# 12/12 [==============================] - 1s 106ms/step - loss: 0.2585 - accuracy: 0.8839 - val_loss: 1.0810 - val_accuracy: 0.6354
# Epoch 89/100
# 12/12 [==============================] - 1s 108ms/step - loss: 0.1980 - accuracy: 0.9235 - val_loss: 1.3136 - val_accuracy: 0.6354
# Epoch 90/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.1936 - accuracy: 0.9292 - val_loss: 1.3983 - val_accuracy: 0.6250
# Epoch 91/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.2633 - accuracy: 0.9122 - val_loss: 1.2241 - val_accuracy: 0.6354
# Epoch 92/100
# 12/12 [==============================] - 1s 99ms/step - loss: 0.2797 - accuracy: 0.8669 - val_loss: 1.1040 - val_accuracy: 0.6042
# Epoch 93/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.2788 - accuracy: 0.8839 - val_loss: 1.1585 - val_accuracy: 0.6354
# Epoch 94/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.2485 - accuracy: 0.9037 - val_loss: 1.2057 - val_accuracy: 0.6042
# Epoch 95/100
# 12/12 [==============================] - 1s 98ms/step - loss: 0.3133 - accuracy: 0.8527 - val_loss: 1.3945 - val_accuracy: 0.6354
# Epoch 96/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.2346 - accuracy: 0.8895 - val_loss: 1.4270 - val_accuracy: 0.5521
# Epoch 97/100
# 12/12 [==============================] - 1s 105ms/step - loss: 0.2129 - accuracy: 0.9089 - val_loss: 1.4614 - val_accuracy: 0.5833
# Epoch 98/100
# 12/12 [==============================] - 1s 108ms/step - loss: 0.2727 - accuracy: 0.8895 - val_loss: 1.6311 - val_accuracy: 0.6250
# Epoch 99/100
# 12/12 [==============================] - 1s 105ms/step - loss: 0.2422 - accuracy: 0.9008 - val_loss: 1.3844 - val_accuracy: 0.5417
# Epoch 100/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.2100 - accuracy: 0.9320 - val_loss: 1.3881 - val_accuracy: 0.5521

# %%
# 텐서보드를 이용한 시각화
# ttensorboard --logdir=/Users/smk0728/Desktop/D_T_S/chap6/img/log6-1/
